# %% [markdown]
# # <font color = blue>**Exploring Ecommerce dataset using Google BigQuery**</font>

# %% [markdown]
# **Task 1. Star the lab project in BigQuery**
#
# In this section you add the data-to-insights project to your environment resources.
#
# 1. Click Navigation menu > BigQuery
#
#
# 2. The Welcome to BigQuery in the Cloud Console message box opens.
# Note: The Welcome to BigQuery in the Cloud Console message box provides a link to the quickstart guide and UI updates.
#
# 3. Click Done.
#
# 4. BigQuery public datasets are not displayed by default in the BigQuery web UI so you'll open the public datasets project.
#
# 5. Click + Add Data.
#
# 6. Select Star a project by name.
#
# 7. For Project name, enter data-to-insights.
#
# 8. Click Star.
#
# 9. In the explorer pane, you will see the data-to-insights project starred.

# %%
from google.colab import files
from IPython.display import Image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-61f20128-f31e-40b5-a00a-30d17458c9d9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-61f20128-f31e-40b5-a00a-30d17458c9d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img1.png', width = 800)

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c1a7ee74-109f-439f-99d2-7bb54867ea57" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c1a7ee74-109f-439f-99d2-7bb54867ea57">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img2.png', width = 800)

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-074ab21a-ac2a-4cfd-8e27-12ee5441a390" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-074ab21a-ac2a-4cfd-8e27-12ee5441a390">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img3.png', width = 800)

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4863bbe4-2861-4b90-a13d-3e55aedec94d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4863bbe4-2861-4b90-a13d-3e55aedec94d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img4.png', width = 500)

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bed6f548-47ec-46ae-a587-dafd5ca962b3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bed6f548-47ec-46ae-a587-dafd5ca962b3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img5.png', width = 600)

# %% [markdown]
# **Task 2. Explore ecommerce data and identify duplicate records**
#
# Scenario: Your data analyst team exported the Google Analytics logs for an ecommerce website into BigQuery and created a new table of all the raw ecommerce visitor session data.
#
# 1. Explore the all_sessions_raw table data:
#
# 2. Expand data-to-insights project.
#
# 3. Expand ecommerce.
#
# 4. Click all_sessions_raw.
#
# 5. In the right pane, a section opens that provides 3 views of the table data:
#
#   Schema tab: Field name, Type, Mode, and Description; the logical constraints used to organize the data.
#
#   Details tab: Table metadata
#
#   Preview tab: Table preview
#
# Click the Details tab to view the table metadata.

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3865ba28-c059-4f5e-9f3b-926760fa6e76" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3865ba28-c059-4f5e-9f3b-926760fa6e76">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img6.png', width = 500)

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a6b1dacf-9532-4194-887c-2e4bb52296f9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a6b1dacf-9532-4194-887c-2e4bb52296f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img7.png', width = 500)

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8a814a32-f55c-4465-aa80-c5b4f4539ffc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8a814a32-f55c-4465-aa80-c5b4f4539ffc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img8.png', width = 500)

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7aad4f91-a0e1-4264-a6a6-caf0523460d5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7aad4f91-a0e1-4264-a6a6-caf0523460d5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img9.png', width = 500)

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ce06c7ff-7b83-4f57-87b0-a67116b3f25e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ce06c7ff-7b83-4f57-87b0-a67116b3f25e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img10.png', width = 500)

# %% [markdown]
# **Task 3: Identify duplicate rows**
#
# Seeing a sample amount of data may give you greater intuition for what is included in the dataset. To preview sample rows from the table without using SQL, click the Preview tab.
#
# 1. Scan and scroll through the rows. There is no singular field that uniquely identifies a row, so you need advanced logic to identify duplicate rows.
#
# 2. Your query uses the SQL GROUP BY function on every field and counts (COUNT) where there are rows that have the same values across every field.
#
# 3. **If every field is unique, the COUNT will return 1** as there are no other groupings of rows with the exact same value for all fields.
#
# 4. **If there is a row with the same values for all fields, they will be grouped together and the COUNT will be greater than 1**. The last part of the query is an aggregation filter using HAVING to only show the results that have a COUNT of duplicates greater than 1.

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bd389f2d-c1d1-4cb9-942a-5f096a5b81df" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bd389f2d-c1d1-4cb9-942a-5f096a5b81df">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img11.png', width = 800)

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-99198f8d-4140-4195-9818-3b93b3efea12" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-99198f8d-4140-4195-9818-3b93b3efea12">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img12.png', width = 800)

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-33648ebc-2e7b-4fc5-b156-26ba67da2c4f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-33648ebc-2e7b-4fc5-b156-26ba67da2c4f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img13.png', width = 800)

# %% [markdown]
# **Task 4: Identify duplicate values in 'all_sessions_table'**
#
# Analyze the new all_sessions table
# In this section you use a deduplicated table called all_sessions.
#
# Scenario: Your data analyst team has provided you with this query, and your schema experts have identified the key fields that must be unique for each record per your schema.
#
# Run the query to confirm that no duplicates exist, this time in the all_sessions table:

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e45f59e5-f378-48cf-8610-9eda98be0d2c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e45f59e5-f378-48cf-8610-9eda98be0d2c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img14.png', width = 800)

# %% [markdown]
# As per the result, there are no duplicate values in the dataset.

# %% [markdown]
# **Task 5. Write a query that shows total unique visitors for all_sessions table**
#
# In this section, you query for insights on the ecommerce dataset.
#
# Write a query that shows total unique visitors
# Your query determines the total views by counting product_views and the number of unique visitors by counting fullVisitorID.

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6954c995-825e-44bc-a2b5-3f0255ecb087" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6954c995-825e-44bc-a2b5-3f0255ecb087">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img15.png', width = 800)

# %% [markdown]
# **Task 6: Write a query that shows total unique visitors(fullVisitorID) by the referring site (channelGrouping)**

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7878ddc7-e418-4524-9c1c-91a44f7d3778" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7878ddc7-e418-4524-9c1c-91a44f7d3778">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img16.png', width = 800)

# %% [markdown]
# **Task 7: Find top 5 Product details for type 'Page' from all_sessions table**
#
# In Google Analytics, a visitor can "view" a product during the following interaction types: 'page', 'screenview', 'event', 'transaction', 'item', 'social', 'exception', 'timing'. For our purposes, simply filter for only type = 'PAGE'.
#
# Here in product details one can consider v2productName as Prodtct name and count od all columns as product views.

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c3ec9ada-4cf1-4c95-ba65-c123a56f8203" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c3ec9ada-4cf1-4c95-ba65-c123a56f8203">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img17.png', width = 800)

# %% [markdown]
# **Task 8: Modify the same query using 'with clause'. Define unique products viewed by customer first**
#
# Refine the query to no longer double-count product views for visitors who have viewed a product many times. Each distinct product view should only count once per visitor.

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d9e101f8-119a-4b26-b147-59fa673515f8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d9e101f8-119a-4b26-b147-59fa673515f8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img18.png', width = 800)

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f02e5c91-112c-498e-a12e-99b8506e2759" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f02e5c91-112c-498e-a12e-99b8506e2759">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img19.png', width = 800)

# %% [markdown]
# **Task 9: Modify the above query to find total number of distinct products ordered (i.e. count productQuantity) and the total number (sum productQuantity) of total units ordered.**

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-69283491-e5ae-47b6-9f1a-062f3a8e431a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-69283491-e5ae-47b6-9f1a-062f3a8e431a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img20.png', width = 800)

# %% [markdown]
# **Task 10: Modify the above query to find Averagae per orders as well along with total number of distinct products ordered (i.e. count productQuantity) and the total number (sum productQuantity) of total units ordered.**
#
# Here Avg_per_orders = (Sum productQuantity/Count productQuantity)

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-93a40abf-07e7-4d75-85e7-403b3682ff8b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-93a40abf-07e7-4d75-85e7-403b3682ff8b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img21.png', width = 800)

# %% [markdown]
# **Task 11: Calculate a conversion rate**
#
# Write a conversion rate query for products with these qualities:
#
# More than 1000 units were added to a cart or ordered AND are not frisbees

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2caffe45-8a7a-4942-9cb4-9bf89feedfe9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2caffe45-8a7a-4942-9cb4-9bf89feedfe9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img22.png', width= 800)

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dc58bb99-4029-4ba9-bb7e-d5bb1acbb542" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dc58bb99-4029-4ba9-bb7e-d5bb1acbb542">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img23.png', width = 800)

# %% [markdown]
# **Task 12: Track visitor checkout progress**
#
# Write a query that shows the eCommerceAction_type and the distinct count of fullVisitorId associated with each type.

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-65f776a2-f6ba-4da5-8634-f1abd3625755" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-65f776a2-f6ba-4da5-8634-f1abd3625755">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img24.png', width = 800)

# %% [markdown]
# **Task 13: Use a Case Statement to add a new column to your previous query to display the eCommerceAction_type label (such as “Completed purchase”)**
#
# You are given this mapping for the action type:
#
# Unknown = 0
#
# Click through of product lists = 1
#
# Product detail views = 2
#
# Add product(s) to cart = 3
#
# Remove product(s) from cart = 4
#
# Check out = 5
#
# Completed purchase = 6
#
# Refund of purchase = 7
#
# Checkout options = 8

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-73520eeb-3650-425b-ab79-b627cf31673c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-73520eeb-3650-425b-ab79-b627cf31673c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img25.png', width = 800)

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a8b3fda5-7049-4cfb-9836-7fb96e4f8172" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a8b3fda5-7049-4cfb-9836-7fb96e4f8172">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img26.png', width = 800)

# %% [markdown]
# **Task 14: Track abandoned carts from high quality sessions**
#
# Write a query using aggregation functions that returns the unique session IDs of those visitors who have added a product to their cart but never completed checkout (abandoned their shopping cart).

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3cfdec35-a3c7-4d3c-840d-64a733cf9751" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3cfdec35-a3c7-4d3c-840d-64a733cf9751">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img27.png', width = 800)

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-52c704ed-c879-4da3-98b6-58b13b837ea1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-52c704ed-c879-4da3-98b6-58b13b837ea1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Lab1_img28.png', width = 800)
